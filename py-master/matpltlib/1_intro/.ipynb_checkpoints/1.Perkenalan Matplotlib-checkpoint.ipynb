# %% [markdown]
# # Import library yang akan digunakan

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Import value yang akan dicari

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %% [markdown]
# # Mulai membuat function

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='b',linewidth=2, linestyle='solid')
